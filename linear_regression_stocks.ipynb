# %% [markdown]
# # Youtube video: https://www.youtube.com/watch?v=JcI5Vnw0b2c&t=8s

# %%
# !pip install quandl

# %%
import pandas as pd
import quandl

# %%
quandl.ApiConfig.api_key = "2gddfUEmLJKFctCegpkH"
df = quandl.get('WIKI/GOOGL')
df.head()
